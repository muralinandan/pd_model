# %%
import os
import python_speech_features
from python_speech_features import mfcc
from python_speech_features import logfbank
import scipy.io.wavfile as wav
import librosa
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
input_dir = os.path.join(os.getcwd(),"External Data/")
updrs_data_file = os.path.join(input_dir,"parkinsons_updrs.data")

tele_file = os.path.join(os.getcwd(),"External Data/tele.csv")

# %%
updrs_data = pd.read_csv(updrs_data_file)

tele_data = pd.read_csv(tele_file)
temp_data = tele_data

# %%
updrs_data
# Out:
#       subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0            1   72    0     5.6431       28.199       34.398    0.00662
# 1            1   72    0    12.6660       28.447       34.894    0.00300
# 2            1   72    0    19.6810       28.695       35.389    0.00481
# 3            1   72    0    25.6470       28.905       35.810    0.00528
# 4            1   72    0    33.6420       29.187       36.375    0.00335
# ...        ...  ...  ...        ...          ...          ...        ...
# 5870        42   61    0   142.7900       22.485       33.485    0.00406
# 5871        42   61    0   149.8400       21.988       32.988    0.00297
# 5872        42   61    0   156.8200       21.495       32.495    0.00349
# 5873        42   61    0   163.7300       21.007       32.007    0.00281
# 5874        42   61    0   170.7300       20.513       31.513    0.00282
#
#       Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# ...

# %%
tele_data.to_csv(tele_file, index=False)
